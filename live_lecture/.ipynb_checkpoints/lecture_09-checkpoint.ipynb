# %% [markdown]
# - Procedural Oriented Programming - POP
# - Object Oriented Progamming - OOP

# %% [markdown]
# Object:
# - Properties/ Attribute: static
# - Action / Method / Function: Dynamic

# %% [markdown]
# Dog:
# - Attribute: hair color, eyes color, 4 legs, ...
# - Method: bark, run, ...

# %% [markdown]
# ![](https://codelearn.io/Media/Default/Users/DatTrann/OOP/Object-Oriented-Programming-Concepts.jpg)

# %% [markdown]
# - Class: như 1 cái khuôn làm bánh. Khuôn mẫu để tạo ra đối tượng. VD: class Dog.
# - Object: chính là cái bánh cụ thể nào đó. VD: chó đốm, chó mực, ..
# - Instance: Là 1 thể hiện của class, đó chính là Object. Object là 1 instance của class
# - Khi làm 1 trang web, thì có rất nhiều nguời, tác vụ nào đó lặp đi lặp lại. Lúc đó chúng ta tạo ra class để sử dụng lại

# %%
# !pip install pandas-gbq
# Out:
# ...
#      |████████████████████████████████| 19.1 MB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 172 kB 3.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 2.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 205 kB 3.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 111 kB 3.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 207 kB 3.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 2.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 784 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 75 kB 4.5 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 45 kB 7.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 4.2 MB 6.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.8 MB 510 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 192 kB 2.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 77 kB 3.4 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
from google.oauth2 import service_account

# %%
url = '/Users/nguyen_truong/Downloads/testing-1-338610-dd0251bf4a94.json'
connection = service_account.Credentials.from_service_account_file(url)

# %%
connection

# %%
query = 'SELECT * FROM `bigquery-public-data.iowa_liquor_sales.sales` LIMIT 1000'
df = pd.read_gbq(query, 'testing-1-338610', credentials=connection)

# %%
df
# Out:
#     invoice_and_item_number        date store_number  \
# 0           INV-25210600054  2020-02-13         3385
# 1              S23115100025  2014-12-22         5004
# 2              S18402900152  2014-04-14         4312
# 3              S14219300007  2013-08-29         4844
# 4              S24682700083  2015-03-24         2604
# ..                      ...         ...          ...
# 995         INV-14961300011  2018-10-10         5666
# 996            S06123700006  2012-06-19         4561
# 997         INV-00662000002  2016-10-03         3525
# 998         INV-19983000001  2019-06-13         4971
# 999         INV-10082200077  2018-01-30         3385
#
#                               store_name                  address  \
# 0         Sam's Club 8162 / Cedar Rapids  2605 Blairs Ferry Rd NE
# 1                   Ida Grove Food Pride    200 SUSAN LAWRENCE DR
# 2           I-80 Liquor / Council Bluffs        2411 S 24TH ST #1
# ...

# %% [markdown]
# - Database: thuật ngữ chung chỉ nơi chứa dữ liệu
# - Server: 1 cái máy tính hoạt động: CPU, RAM, Disk
# - SQL Server: Là 1 server sử dụng ngôn ngữ SQL để truy vấn
# - SQL Server Management System: Hệ quản trị cơ sở dữ liệu, là 1 phần mềm giúp kết nối đến SQL server.
# - SQL Server Management System = SQL Server + SQL
# - SQL không phải là ngôn ngữ lập trình --> Nó là ngôn ngữ truy vấn có cấu trúc (Strutural Query Language)

# %% [markdown]
# CRUD:
# - Create
# - Read
# - Update
# - Delete
