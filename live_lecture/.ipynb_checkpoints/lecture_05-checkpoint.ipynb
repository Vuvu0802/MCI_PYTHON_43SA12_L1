# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - Series
# - DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1. Create DataFrame

# %%
dict_1 = {'name': ['Truong', 'Thach', 'Hang'], 'age': [28, 23, 43]}
dict_1
# Out:
# {'name': ['Truong', 'Thach', 'Hang'], 'age': [28, 23, 43]}

# %%
df = pd.DataFrame(dict_1)
df
# Out:
#      name  age
# 0  Truong   28
# 1   Thach   23
# 2    Hang   43

# %%
import yfinance as yf

# %%
tesla = yf.download('TSLA', start='2015-01-01', end='2022-01-06')
tesla
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2014-12-31    44.618000    45.136002    44.450001    44.481998    44.481998
# 2015-01-02    44.574001    44.650002    42.652000    43.862000    43.862000
# 2015-01-05    42.910000    43.299999    41.431999    42.018002    42.018002
# 2015-01-06    42.012001    42.840000    40.841999    42.256001    42.256001
# 2015-01-07    42.669998    42.956001    41.956001    42.189999    42.189999
# ...                 ...          ...          ...          ...          ...
# 2021-12-30  1061.329956  1095.550049  1053.150024  1070.339966  1070.339966
# 2021-12-31  1073.439941  1082.000000  1054.589966  1056.780029  1056.780029
# 2022-01-03  1147.750000  1201.069946  1136.040039  1199.780029  1199.780029
# 2022-01-04  1189.550049  1208.000000  1123.050049  1149.589966  1149.589966
# ...

# %%
series = tesla.Close
series
# Out:
# Date
# 2014-12-31      44.481998
# 2015-01-02      43.862000
# 2015-01-05      42.018002
# 2015-01-06      42.256001
# 2015-01-07      42.189999
#                  ...
# 2021-12-30    1070.339966
# 2021-12-31    1056.780029
# 2022-01-03    1199.780029
# 2022-01-04    1149.589966
# 2022-01-05    1088.119995
# Name: Close, Length: 1767, dtype: float64

# %%
series_2 = pd.Series(np.linspace(1, 20, 20))
series_2
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      6.0
# 6      7.0
# 7      8.0
# 8      9.0
# 9     10.0
# 10    11.0
# 11    12.0
# 12    13.0
# 13    14.0
# 14    15.0
# 15    16.0
# 16    17.0
# 17    18.0
# 18    19.0
# 19    20.0
# dtype: float64

# %%
series_2.to_frame()
# Out:
#        0
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    7.0
# 7    8.0
# 8    9.0
# 9   10.0
# 10  11.0
# 11  12.0
# 12  13.0
# 13  14.0
# 14  15.0
# 15  16.0
# 16  17.0
# 17  18.0
# 18  19.0
# 19  20.0

# %% [markdown]
# ### 2. Indexing

# %% [markdown]
# ### 3. Slicing

# %% [markdown]
# ### 4. Masking

# %% [markdown]
# ### 5. Statistic

# %% [markdown]
# ### 6. I/O

# %%
# comma separated values --> text with values separated by comma
df = pd.read_csv('duplicated.csv')
df
# Out:
#           CUSID  REF_TIME    SEGMENT  LABEL_MONTH   KIND  REF_MONTH  \
# 0      10102112  20200930  TRUE_MASS       202010  VALID   202009.0
# 1      10102112  20200930  TRUE_MASS       202010  VALID   202009.0
# 2      10109425  20200831   TRUE_AFF       202009  TRAIN   202008.0
# 3      10109425  20200831   TRUE_AFF       202009  TRAIN   202008.0
# 4      10115395  20210331   TRUE_AFF       202104   EVAL   202103.0
# ...         ...       ...        ...          ...    ...        ...
# 32605  88888883  20210331   TRUE_MAF       202104   EVAL   202103.0
# 32606  99009900  20210331   TRUE_AFF       202104   EVAL   202103.0
# 32607  99009900  20210331   TRUE_AFF       202104   EVAL   202103.0
# 32608  99699996  20210331   TRUE_AFF       202104   EVAL   202103.0
# 32609  99699996  20210331   TRUE_AFF       202104   EVAL   202103.0
#
#        CARD_USE_CREDIT_DEBIT  CARD_GOLD  CARD_CLASSIC  CARD_FAST  ...  \
# 0                        1.0        1.0           NaN        NaN  ...
# ...

# %%
# serialize
df[['CUSID', 'REF_TIME', 'SEGMENT']].to_excel('data.xlsx', index=False)

# %%
df_2 = pd.read_excel('data.xlsx')
df_2
# Out:
#           CUSID  REF_TIME    SEGMENT
# 0      10102112  20200930  TRUE_MASS
# 1      10102112  20200930  TRUE_MASS
# 2      10109425  20200831   TRUE_AFF
# 3      10109425  20200831   TRUE_AFF
# 4      10115395  20210331   TRUE_AFF
# ...         ...       ...        ...
# 32605  88888883  20210331   TRUE_MAF
# 32606  99009900  20210331   TRUE_AFF
# 32607  99009900  20210331   TRUE_AFF
# 32608  99699996  20210331   TRUE_AFF
# 32609  99699996  20210331   TRUE_AFF
#
# [32610 rows x 3 columns]

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df_3 = pd.read_csv(url, delimiter='\t')

# %%
df_3.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df_3.to_csv('chipotle.csv', index=False)

# %% [markdown]
# - Absolute Path: 'C:\Document\GitHub\MCI...'
# - Relative Path: compared to working file

# %%
absolute_path = '/Users/truongnm/Downloads/chipotle.csv'
df_absolute = pd.read_csv(absolute_path)
df_absolute
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
relative_path = '../chipotle.csv'
df_04 = pd.read_csv(relative_path)
df_04
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...
