# %% [markdown]
# # Fictitious Names

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](https://miro.medium.com/max/1200/1*9eH1_7VbTZPZd9jBiGIyNA.png)

# %% [markdown]
# ### Introduction:
#
# This time you will create a data again
#
# Special thanks to [Chris Albon](http://chrisalbon.com/) for sharing the dataset and materials.
# All the credits to this exercise belongs to him.
#
# In order to understand about it go [here](https://blog.codinghorror.com/a-visual-explanation-of-sql-joins/).
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create the 3 DataFrames based on the following raw data

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %% [markdown]
# ### Step 3. Assign each to a variable called data1, data2, data3

# %%
data1 = pd.DataFrame(raw_data_1)
data2 = pd.DataFrame(raw_data_2)
data3 = pd.DataFrame(raw_data_3)

# %%
data1.head(2)
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman

# %%
data2.head(2)
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black

# %%
data3.head(2)
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15

# %% [markdown]
# ### Step 4. Join the two dataframes along rows and assign all_data

# %%
all_data = pd.concat([data1, data2], ignore_index=True)
all_data.head(2)
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman

# %% [markdown]
# ### Step 5. Join the two dataframes along columns and assing to all_data_col

# %%
all_data_col = all_data.merge(data3, on='subject_id', how='inner')
all_data_col.head(2)
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15

# %%
all_data.shape, data3.shape, all_data_col.shape
# Out:
# ((10, 3), (10, 2), (9, 4))

# %% [markdown]
# ### Step 6. Print data3

# %% [markdown]
# ### Step 7. Merge all_data and data3 along the subject_id value

# %% [markdown]
# ### Step 8. Merge only the data that has the same 'subject_id' on both data1 and data2

# %%
data1
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
data2
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data1.merge(data2, on='subject_id', how='left', suffixes=('_left', '_right'))
# Out:
#   subject_id first_name_left last_name_left first_name_right last_name_right
# 0          1            Alex       Anderson              NaN             NaN
# 1          2             Amy       Ackerman              NaN             NaN
# 2          3           Allen            Ali              NaN             NaN
# 3          4           Alice           Aoni            Billy          Bonder
# 4          5          Ayoung        Atiches            Brian           Black

# %% [markdown]
# ### Step 9. Merge all values in data1 and data2, with matching records from both sides where available.

# %%
data1.merge(data2, on='subject_id', how='outer', suffixes=('_left', '_right'))
# Out:
#   subject_id first_name_left last_name_left first_name_right last_name_right
# 0          1            Alex       Anderson              NaN             NaN
# 1          2             Amy       Ackerman              NaN             NaN
# 2          3           Allen            Ali              NaN             NaN
# 3          4           Alice           Aoni            Billy          Bonder
# 4          5          Ayoung        Atiches            Brian           Black
# 5          6             NaN            NaN             Bran         Balwner
# 6          7             NaN            NaN            Bryce           Brice
# 7          8             NaN            NaN            Betty          Btisan
